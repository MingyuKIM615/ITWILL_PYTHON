# %% [markdown]
# <a href="https://colab.research.google.com/github/MingyuKIM615/ITWILL_PYTHON/blob/master/py25_movielens.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 파일이 저장된 경로
movies_file ='https://github.com/wesm/pydata-book/raw/2nd-edition/datasets/movielens/movies.dat'

# %% [markdown]
# * movies.dat 파일을 읽고, DataFrame 생성.
# * DataFrame 탐색.
# * 장르가 'Animation'인 영화는 몇 개?
# * 장르가 로맨틱 코미디인 영화는 몇 개?
# * 어떤 장르의 영화가 가장 많은가?

# %%
movies_colnames = ['mobieid', 'title', 'genre']

# %%
movies = pd.read_csv(movies_file, sep='::', names=movies_colnames, engine='python')
movies
# Out:
#       mobieid                               title  \
# 0           1                    Toy Story (1995)
# 1           2                      Jumanji (1995)
# 2           3             Grumpier Old Men (1995)
# 3           4            Waiting to Exhale (1995)
# 4           5  Father of the Bride Part II (1995)
# ...       ...                                 ...
# 3878     3948             Meet the Parents (2000)
# 3879     3949          Requiem for a Dream (2000)
# 3880     3950                    Tigerland (2000)
# 3881     3951             Two Family House (2000)
# 3882     3952               Contender, The (2000)
#
#                              genre
# 0      Animation|Children's|Comedy
# 1     Adventure|Children's|Fantasy
# 2                   Comedy|Romance
# 3                     Comedy|Drama
# 4                           Comedy
# ...                            ...
# 3878                        Comedy
# 3879                         Drama
# 3880                         Drama
# 3881                         Drama
# 3882                Drama|Thriller
#
# [3883 rows x 3 columns]

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3883 entries, 0 to 3882
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   mobieid  3883 non-null   int64
#  1   title    3883 non-null   object
#  2   genre    3883 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 91.1+ KB

# %%
movies.describe()
# Out:
#            mobieid
# count  3883.000000
# mean   1986.049446
# std    1146.778349
# min       1.000000
# 25%     982.500000
# 50%    2010.000000
# 75%    2980.500000
# max    3952.000000

# %%
movies.head()
# Out:
#    mobieid                               title                         genre
# 0        1                    Toy Story (1995)   Animation|Children's|Comedy
# 1        2                      Jumanji (1995)  Adventure|Children's|Fantasy
# 2        3             Grumpier Old Men (1995)                Comedy|Romance
# 3        4            Waiting to Exhale (1995)                  Comedy|Drama
# 4        5  Father of the Bride Part II (1995)                        Comedy

# %%
movies.tail()
# Out:
#       mobieid                       title           genre
# 3878     3948     Meet the Parents (2000)          Comedy
# 3879     3949  Requiem for a Dream (2000)           Drama
# 3880     3950            Tigerland (2000)           Drama
# 3881     3951     Two Family House (2000)           Drama
# 3882     3952       Contender, The (2000)  Drama|Thriller

# %%
# Animation 장르의 영화
animations = movies[movies['genre'].str.contains('Animation')]
animations
# Out:
#       mobieid                          title  \
# 0           1               Toy Story (1995)
# 12         13                   Balto (1995)
# 47         48              Pocahontas (1995)
# 236       239          Goofy Movie, A (1995)
# 241       244        Gumby: The Movie (1995)
# ...       ...                            ...
# 3690     3759      Fun and Fancy Free (1947)
# 3706     3775         Make Mine Music (1946)
# 3707     3776             Melody Time (1948)
# 3730     3799  Pokémon the Movie 2000 (2000)
# 3875     3945      Digimon: The Movie (2000)
#
#                                      genre
# 0              Animation|Children's|Comedy
# 12                    Animation|Children's
# 47    Animation|Children's|Musical|Romance
# 236    Animation|Children's|Comedy|Romance
# 241                   Animation|Children's
# ...                                    ...
# 3690          Animation|Children's|Musical
# 3706          Animation|Children's|Musical
# 3707          Animation|Children's|Musical
# 3730                  Animation|Children's
# 3875        Adventure|Animation|Children's
#
# [105 rows x 3 columns]

# %%
len(animations)
# Out:
# 105

# %%
# 로맨특 코미디 장르 - 장르 컬럼에 'Romance'와 'Comedy'가 포함되어 있는 영화들
romantic_comedies = movies[(movies['genre'].str.contains('Romance')) &
                          (movies['genre'].str.contains('Comedy'))]
romantic_comedies
# Out:
#       mobieid                           title                 genre
# 2           3         Grumpier Old Men (1995)        Comedy|Romance
# 6           7                  Sabrina (1995)        Comedy|Romance
# 10         11  American President, The (1995)  Comedy|Drama|Romance
# 38         39                 Clueless (1995)        Comedy|Romance
# 63         64            Two if by Sea (1996)        Comedy|Romance
# ...       ...                             ...                   ...
# 3679     3748               Match, The (1999)        Comedy|Romance
# 3759     3829          Mad About Mambo (2000)        Comedy|Romance
# 3804     3874     Couch in New York, A (1996)        Comedy|Romance
# 3815     3885               Love & Sex (2000)        Comedy|Romance
# 3839     3909             Woman on Top (2000)        Comedy|Romance
#
# [204 rows x 3 columns]

# %%
len(romantic_comedies)
# Out:
# 204

# %%
# 가장 많이 나오는 장르
genres = [] # 개별 영화 장르를 저장할 빈 리스트
for s in movies['genre']:
  genres.extend(s.split(sep='|'))
len(genres)
# Out:
# 6408

# %%
genre_counts = pd.value_counts(genres)
genre_counts #> Series
# Out:
# Drama          1603
# Comedy         1200
# Action          503
# Thriller        492
# Romance         471
# Horror          343
# Adventure       283
# Sci-Fi          276
# Children's      251
# Crime           211
# War             143
# Documentary     127
# Musical         114
# Mystery         106
# Animation       105
# Fantasy          68
# Western          68
# Film-Noir        44
# dtype: int64

# %%
# 장르 상위 7개 시각화.
top7 = genre_counts.head(n=7)
top7
# Out:
# Drama        1603
# Comedy       1200
# Action        503
# Thriller      492
# Romance       471
# Horror        343
# Adventure     283
# dtype: int64

# %%
sns.barplot(x=top7.values,y=top7.index )
plt.show()

# %%
bottom7 = genre_counts.tail(n=7)
bottom7
# Out:
# Documentary    127
# Musical        114
# Mystery        106
# Animation      105
# Fantasy         68
# Western         68
# Film-Noir       44
# dtype: int64

# %%
sns.barplot(x=bottom7.values, y=bottom7.index)
plt.show()

# %%
genre_counts_df = genre_counts.reset_index()
genre_counts_df.columns = ['genre', 'counts']
genre_counts_df
# Out:
#           genre  counts
# 0         Drama    1603
# 1        Comedy    1200
# 2        Action     503
# 3      Thriller     492
# 4       Romance     471
# 5        Horror     343
# 6     Adventure     283
# 7        Sci-Fi     276
# 8    Children's     251
# 9         Crime     211
# 10          War     143
# 11  Documentary     127
# 12      Musical     114
# 13      Mystery     106
# 14    Animation     105
# 15      Fantasy      68
# 16      Western      68
# 17    Film-Noir      44

# %%
sns.barplot(x='counts', y='genre', data=genre_counts_df)
plt.show()

# %%
# 연도별 영화 개봉 숫자 시각화

# for문을 이용해서 title의 연도만 추출한 후 연도 리스트에 저장.
movie_years = []
for t in movies['title']:
  movie_years.append(int(t[-5:-1]))

# 정열
movie_years.sort()
print(movie_years)
# Out:
# [1919, 1919, 1919, 1920, 1920, 1921, 1922, 1922, 1923, 1923, 1923, 1925, 1925, 1925, 1925, 1925, 1925, 1926, 1926, 1926, 1926, 1926, 1926, 1926, 1926, 1927, 1927, 1927, 1927, 1927, 1927, 1928, 1928, 1928, 1929, 1929, 1929, 1930, 1930, 1930, 1930, 1930, 1930, 1930, 1931, 1931, 1931, 1931, 1931, 1931, 1931, 1932, 1932, 1932, 1932, 1932, 1932, 1932, 1933, 1933, 1933, 1933, 1933, 1933, 1933, 1934, 1934, 1934, 1934, 1934, 1934, 1934, 1935, 1935, 1935, 1935, 1935, 1935, 1936, 1936, 1936, 1936, 1936, 1936, 1936, 1936, 1937, 1937, 1937, 1937, 1937, 1937, 1937, 1937, 1937, 1937, 1937, 1938, 1938, 1938, 1938, 1938, 1938, 1939, 1939, 1939, 1939, 1939, 1939, 1939, 1939, 1939, 1939, 1939, 1940, 1940, 1940, 1940, 1940, 1940, 1940, 1940, 1940, 1940, 1940, 1940, 1940, 1940, 1940, 1940, 1940, 1940, 1940, 1941, 1941, 1941, 1941, 1941, 1941, 1941, 1941, 1941, 1941, 1941, 1942, 1942, 1942, 1942, 1942, 1942, 1942, 1942, 1942, 1942, 1942, 1942, 1942, 1943, 1943, 1943, 1943, 1943, 1943, 1943, 1943, 1943, 1943, 1944, 1944, 1944, 1944, 1944, 1944, 1944, 1944, 1944, 1944, 1944, 1944, 1944, 1945, 1945, 1945, 1945, 1945, 1945, 1945, 1945, 1945, 1945, 1945, 1946, 1946, 1946, 1946, 1946, 1946, 1946, 1946, 1946, 1946, 1946, 1946, 1946, 1947, 1947, 1947, 1947, 1947, 1947, 1947, 1947, 1947, 1947, 1947, 1947, 1947, 1947, 1948, 1948, 1948, 1948, 1948, 1948, 1948, 1948, 1948, 1948, 1948, 1948, 1949, 1949, 1949, 1949, 1949, 1949, 1949, 1949, 1949, 1949, 1950, 1950, 1950, 1950, 1950, 1950, 1950, 1950, 1950, 1950, 1950, 1950, 1950, 1950, 1951, 1951, 1951, 1951, 1951, 1951, 1951, 1951, 1951, 1951, 1951, 1951, 1952, 1952, 1952, 1952, 1952, 1952, 1952, 1952, 1952, 1952, 1952, 1953, 1953, 1953, 1953, 1953, 1953, 1953, 1953, 1953, 1953, 1953, 1953, 1953, 1953, 1954, 1954, 1954, 1954, 1954, 1954, 1954, 1954, 1954, 1954, 1954, 1954, 1954, 1954, 1954, 1955, 1955, 1955, 1955, 1955, 1955, 1955, 1955, 1955, 1955, 1955, 1955, 1955, 1955, 1955, 1955, 1955, 1955, 1955, 1956, 1956, 1956, 1956, 1956, 1956, 1956, 1956, 1956, 1956, 1956, 1956, 1956, 1956, 1956, 1956, 1956, 1956, 1956, 1957, 1957, 1957, 1957, 1957, 1957, 1957, 1957, 1957, 1957, 1957, 1957, 1957, 1957, 1957, 1957, 1957, 1957, 1957, 1957, 1958, 1958, 1958, 1958, 1958, 1958, 1958, 1958, 1958, 1958, 1958, 1958, 1958, 1958, 1958, 1958, 1958, 1958, 1958, 1958, 1958, 1958, 1959, 1959, 1959, 1959, 1959, 1959, 1959, 1959, 1959, 1959, 1959, 1959, 1959, 1959, 1959, 1959, 1959, 1959, 1959, 1959, 1959, 1959, 1960, 1960, 1960, 1960, 1960, 1960, 1960, 1960, 1960, 1960, 1960, 1960, 1960, 1960, 1960, 1961, 1961, 1961, 1961, 1961, 1961, 1961, 1961, 1961, 1961, 1961, 1961, 1961, 1961, 1961, 1961, 1961, 1961, 1961, 1962, 1962, 1962, 1962, 1962, 1962, 1962, 1962, 1962, 1962, 1962, 1962, 1962, 1962, 1962, 1962, 1962, 1962, 1962, 1962, 1963, 1963, 1963, 1963, 1963, 1963, 1963, 1963, 1963, 1963, 1963, 1963, 1963, 1963, 1963, 1963, 1963, 1963, 1963, 1963, 1963, 1963, 1963, 1963, 1963, 1964, 1964, 1964, 1964, 1964, 1964, 1964, 1964, 1964, 1964, 1964, 1964, 1964, 1964, 1964, 1964, 1965, 1965, 1965, 1965, 1965, 1965, 1965, 1965, 1965, 1965, 1965, 1965, 1965, 1965, 1965, 1965, 1965, 1965, 1965, 1965, 1966, 1966, 1966, 1966, 1966, 1966, 1966, 1966, 1966, 1966, 1966, 1966, 1967, 1967, 1967, 1967, 1967, 1967, 1967, 1967, 1967, 1967, 1967, 1967, 1967, 1967, 1967, 1967, 1967, 1967, 1967, 1967, 1967, 1967, 1967, 1967, 1968, 1968, 1968, 1968, 1968, 1968, 1968, 1968, 1968, 1968, 1968, 1968, 1968, 1968, 1968, 1968, 1968, 1968, 1968, 1968, 1968, 1968, 1969, 1969, 1969, 1969, 1969, 1969, 1969, 1969, 1969, 1969, 1969, 1969, 1969, 1969, 1969, 1969, 1969, 1969, 1970, 1970, 1970, 1970, 1970, 1970, 1970, 1970, 1970, 1970, 1970, 1970, 1970, 1970, 1970, 1970, 1971, 1971, 1971, 1971, 1971, 1971, 1971, 1971, 1971, 1971, 1971, 1971, 1971, 1971, 1971, 1971, 1971, 1971, 1971, 1971, 1971, 1971, 1971, 1971, 1971, 1971, 1972, 1972, 1972, 1972, 1972, 1972, 1972, 1972, 1972, 1972, 1972, 1972, 1972, 1972, 1972, 1972, 1972, 1972, 1972, 1972, 1972, 1972, 1973, 1973, 1973, 197 ...

# %%
# pandas를 이용해서 리스트를 Series로 변환, 연도 순으로 정열
year_counts = pd.value_counts(movie_years).sort_index()
year_counts
# Out:
# 1919      3
# 1920      2
# 1921      1
# 1922      2
# 1923      3
#        ...
# 1996    345
# 1997    315
# 1998    337
# 1999    283
# 2000    156
# Length: 81, dtype: int64

# %%
# 그래프 그리기
sns.barplot(x=year_counts.index, y=year_counts.values)
plt.show()

# %%
# 10년 단위로 묶어서 구하기.
counts = {}
for year in range(1910, 2001, 10):
  dac_year = f'{year}'
    
  # movie_years에서 10년단위 값 카운트하기
  for y in movie_years:
    if dac_year in counts:
      if year<= y & y < year + 10:
        counts[dac_year] += 1
    else:
      counts[dac_year] = 1

counts
# Out:
# {'1910': 3,
#  '1920': 35,
#  '1930': 78,
#  '1940': 127,
#  '1950': 169,
#  '1960': 192,
#  '1970': 248,
#  '1980': 599,
#  '1990': 2284,
#  '2000': 157}

# %%
counts.values()
counts.keys()
# Out:
# dict_keys(['1910', '1920', '1930', '1940', '1950', '1960', '1970', '1980', '1990', '2000'])

# %%
# Series로 만들기
year_counts2 = pd.Series(data=counts.values(), index=counts.keys())
year_counts2
# Out:
# 1910       3
# 1920      35
# 1930      78
# 1940     127
# 1950     169
# 1960     192
# 1970     248
# 1980     599
# 1990    2284
# 2000     157
# dtype: int64

# %%
# 그래프 그리기
sns.barplot(x=year_counts2.index, y=year_counts2.values, )
plt.show()

# %%
# 연도별 영화 개봉 숫자 시각화
movies.tail()
# Out:
#       mobieid                       title           genre
# 3878     3948     Meet the Parents (2000)          Comedy
# 3879     3949  Requiem for a Dream (2000)           Drama
# 3880     3950            Tigerland (2000)           Drama
# 3881     3951     Two Family House (2000)           Drama
# 3882     3952       Contender, The (2000)  Drama|Thriller

# %%
# 영화 제목 컬럼(title)에서 연도에 해당하는 4자리 문자열을 잘라내고 정수타입으로 변환해서 새로운 컬럼 만듦.
movies['year'] = movies['title'].str[-5:-1].astype('int')

# %%
movies.head()
# Out:
#    mobieid                               title                         genre  \
# 0        1                    Toy Story (1995)   Animation|Children's|Comedy
# 1        2                      Jumanji (1995)  Adventure|Children's|Fantasy
# 2        3             Grumpier Old Men (1995)                Comedy|Romance
# 3        4            Waiting to Exhale (1995)                  Comedy|Drama
# 4        5  Father of the Bride Part II (1995)                        Comedy
#
#    year
# 0  1995
# 1  1995
# 2  1995
# 3  1995
# 4  1995

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3883 entries, 0 to 3882
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   mobieid  3883 non-null   int64
#  1   title    3883 non-null   object
#  2   genre    3883 non-null   object
#  3   year     3883 non-null   int64
# dtypes: int64(2), object(2)
# memory usage: 121.5+ KB

# %%
year_counts = movies['year'].value_counts()
year_counts
# Out:
# 1996    345
# 1995    342
# 1998    337
# 1997    315
# 1999    283
#        ...
# 1923      3
# 1919      3
# 1922      2
# 1920      2
# 1921      1
# Name: year, Length: 81, dtype: int64

# %%
plt.plot(year_counts.index, year_counts.values)
plt.show()

# %%
year = year_counts.sort_index() # Series를 인덱스의 오름차순 정렬을 하고 저장.

# %%
plt.plot(year.index, year.values)
plt.xlabel('Year')
plt.ylabel('Counts')
plt.show()

# %%
plt.bar(x=year_counts.index, height=year_counts.values)
plt.show()

# %% [markdown]
# # DataFrame 합치기(merge)

# %%
# 데이터 파일의 GitHub 경로
movies_file= 'https://github.com/wesm/pydata-book/raw/2nd-edition/datasets/movielens/movies.dat'
ratings_file='https://github.com/wesm/pydata-book/raw/2nd-edition/datasets/movielens/ratings.dat'
users_file='https://github.com/wesm/pydata-book/raw/2nd-edition/datasets/movielens/users.dat'

# %%
# 데이터 파일의 컬럼 이름들
movies_colnames = ['movie_id', 'title', 'genres']
ratings_colnames = ['user_id', 'movie_id', 'rating', 'timestamp']
users_colnames = ['user_id', 'gender', 'age', 'occupation', 'zip_code']

# %%
# 데이터 프레임 생성
movies = pd.read_csv(movies_file, sep='::', engine='python', names=movies_colnames)

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3883 entries, 0 to 3882
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   movie_id  3883 non-null   int64
#  1   title     3883 non-null   object
#  2   genres    3883 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 91.1+ KB

# %%
ratings = pd.read_csv(ratings_file, sep='::', engine = 'python', names=ratings_colnames)

# %%
ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000209 entries, 0 to 1000208
# Data columns (total 4 columns):
#  #   Column     Non-Null Count    Dtype
# ---  ------     --------------    -----
#  0   user_id    1000209 non-null  int64
#  1   movie_id   1000209 non-null  int64
#  2   rating     1000209 non-null  int64
#  3   timestamp  1000209 non-null  int64
# dtypes: int64(4)
# memory usage: 30.5 MB

# %%
ratings.head()
# Out:
#    user_id  movie_id  rating  timestamp
# 0        1      1193       5  978300760
# 1        1       661       3  978302109
# 2        1       914       3  978301968
# 3        1      3408       4  978300275
# 4        1      2355       5  978824291

# %%
movies[movies['movie_id'] == 1193]
# Out:
#       movie_id                                   title genres
# 1176      1193  One Flew Over the Cuckoo's Nest (1975)  Drama

# %%
users = pd.read_csv(users_file, sep='::', engine='python', names=users_colnames)

# %%
users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6040 entries, 0 to 6039
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   user_id     6040 non-null   int64
#  1   gender      6040 non-null   object
#  2   age         6040 non-null   int64
#  3   occupation  6040 non-null   int64
#  4   zip_code    6040 non-null   object
# dtypes: int64(3), object(2)
# memory usage: 236.1+ KB

# %%
users.head()
# Out:
#    user_id gender  age  occupation zip_code
# 0        1      F    1          10    48067
# 1        2      M   56          16    70072
# 2        3      M   25          15    55117
# 3        4      M   45           7    02460
# 4        5      M   25          20    55455

# %%
# rating와 movies를 merge(SQL의 join과 비슷한 기능)
# how 파리미터: join 방식(inner, left, right, outer). 기본값은 'inner'
# on 파리미터: join을 할 때 사용할 컬럼(들)의 이름.
df = pd.merge(left=ratings, right=movies, how='inner', on='movie_id')

# %%
df.head()
# Out:
#    user_id  movie_id  rating  timestamp  \
# 0        1      1193       5  978300760
# 1        2      1193       5  978298413
# 2       12      1193       4  978220179
# 3       15      1193       4  978199279
# 4       17      1193       5  978158471
#
#                                     title genres
# 0  One Flew Over the Cuckoo's Nest (1975)  Drama
# 1  One Flew Over the Cuckoo's Nest (1975)  Drama
# 2  One Flew Over the Cuckoo's Nest (1975)  Drama
# 3  One Flew Over the Cuckoo's Nest (1975)  Drama
# 4  One Flew Over the Cuckoo's Nest (1975)  Drama

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000209 entries, 0 to 1000208
# Data columns (total 6 columns):
#  #   Column     Non-Null Count    Dtype
# ---  ------     --------------    -----
#  0   user_id    1000209 non-null  int64
#  1   movie_id   1000209 non-null  int64
#  2   rating     1000209 non-null  int64
#  3   timestamp  1000209 non-null  int64
#  4   title      1000209 non-null  object
#  5   genres     1000209 non-null  object
# dtypes: int64(4), object(2)
# memory usage: 53.4+ MB

# %%
# df와 users 데이터 프레임을 merge
df = pd.merge(left=df, right=users, on='user_id')

# %%
df.head()
# Out:
#    user_id  movie_id  rating  timestamp  \
# 0        1      1193       5  978300760
# 1        1       661       3  978302109
# 2        1       914       3  978301968
# 3        1      3408       4  978300275
# 4        1      2355       5  978824291
#
#                                     title                        genres  \
# 0  One Flew Over the Cuckoo's Nest (1975)                         Drama
# 1        James and the Giant Peach (1996)  Animation|Children's|Musical
# 2                     My Fair Lady (1964)               Musical|Romance
# 3                  Erin Brockovich (2000)                         Drama
# 4                    Bug's Life, A (1998)   Animation|Children's|Comedy
#
#   gender  age  occupation zip_code
# 0      F    1          10    48067
# 1      F    1          10    48067
# 2      F    1          10    48067
# 3      F    1          10    48067
# 4      F    1          10    48067

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000209 entries, 0 to 1000208
# Data columns (total 10 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   user_id     1000209 non-null  int64
#  1   movie_id    1000209 non-null  int64
#  2   rating      1000209 non-null  int64
#  3   timestamp   1000209 non-null  int64
#  4   title       1000209 non-null  object
#  5   genres      1000209 non-null  object
#  6   gender      1000209 non-null  object
#  7   age         1000209 non-null  int64
#  8   occupation  1000209 non-null  int64
#  9   zip_code    1000209 non-null  object
# dtypes: int64(6), object(4)
# memory usage: 83.9+ MB

# %%
pd.merge(left=pd.merge(left=ratings, right=movies, on='movie_id'),
         right=users, on = 'user_id')
# Out:
#          user_id  movie_id  rating  timestamp  \
# 0              1      1193       5  978300760
# 1              1       661       3  978302109
# 2              1       914       3  978301968
# 3              1      3408       4  978300275
# 4              1      2355       5  978824291
# ...          ...       ...     ...        ...
# 1000204     4211      3791       2  965319075
# 1000205     4211      3806       3  965319138
# 1000206     4211      3840       4  965319197
# 1000207     4211      3766       2  965319138
# 1000208     4211      3834       2  965318885
#
#                                           title                        genres  \
# 0        One Flew Over the Cuckoo's Nest (1975)                         Drama
# 1              James and the Giant Peach (1996)  Animation|Children's|Musical
# 2                           My Fair Lady (1964)               Musical|Romance
# 3                        Erin Brockovich (2000)                         Drama
# 4                          Bug's Life, A (1998)   Animation|Children's|Comedy
# ...                                         ...                           ...
# 1000204                        Footloose (1984)                         Drama
# 1000205                  MacKenna's Gold (1969)                       Western
# 1000206                      Pumpkinhead (1988)                        Horror
# 1000207                Missing in Action (1984)                    Action|War
# 1000208                     Bronco Billy (1980)       Adventure|Drama|Romance
#
#         gender  age  occupation zip_code
# 0            F    1          10    48067
# 1            F    1          10    48067
# 2            F    1          10    48067
# 3            F    1          10    48067
# 4            F    1          10    48067
# ...        ...  ...         ...      ...
# 1000204      M   45           5    77662
# 1000205      M   45           5    77662
# 1000206      M   45           5    77662
# 1000207      M   45           5    77662
# 1000208      M   45           5    77662
#
# [1000209 rows x 10 columns]

# %% [markdown]
# ## 영화 평점 분석

# %%
df['rating'].describe()
# Out:
# count    1.000209e+06
# mean     3.581564e+00
# std      1.117102e+00
# min      1.000000e+00
# 25%      3.000000e+00
# 50%      4.000000e+00
# 75%      4.000000e+00
# max      5.000000e+00
# Name: rating, dtype: float64

# %%
sns.boxplot(y='rating', data=df)
plt.show()

# %%
# 영화 별점의 빈도수
rating_counts = df['rating'].value_counts()
rating_counts
# Out:
# 4    348971
# 3    261197
# 5    226310
# 2    107557
# 1     56174
# Name: rating, dtype: int64

# %%
sns.barplot(x=rating_counts.index, y=rating_counts.values)
plt.xlabel('Rating')
plt.ylabel('Counts')
plt.show()

# %%
df.head()
# Out:
#    user_id  movie_id  rating  timestamp  \
# 0        1      1193       5  978300760
# 1        1       661       3  978302109
# 2        1       914       3  978301968
# 3        1      3408       4  978300275
# 4        1      2355       5  978824291
#
#                                     title                        genres  \
# 0  One Flew Over the Cuckoo's Nest (1975)                         Drama
# 1        James and the Giant Peach (1996)  Animation|Children's|Musical
# 2                     My Fair Lady (1964)               Musical|Romance
# 3                  Erin Brockovich (2000)                         Drama
# 4                    Bug's Life, A (1998)   Animation|Children's|Comedy
#
#   gender  age  occupation zip_code
# 0      F    1          10    48067
# 1      F    1          10    48067
# 2      F    1          10    48067
# 3      F    1          10    48067
# 4      F    1          10    48067

# %% [markdown]
# ## 성별 분석

# %%
# 성별 빈도수
gender_counts = df['gender'].value_counts()
gender_counts
# Out:
# M    753769
# F    246440
# Name: gender, dtype: int64

# %%
sns.barplot(x=gender_counts.index, y=gender_counts.values)
plt.xlabel('Gender')
plt.ylabel('Counts')
plt.show()

# %% [markdown]
# ## 연령대 분석

# %%
age_counts = df['age'].value_counts()
age_counts
# Out:
# 25    395556
# 35    199003
# 18    183536
# 45     83633
# 50     72490
# 56     38780
# 1      27211
# Name: age, dtype: int64

# %%
sns.barplot(x=age_counts.index, y=age_counts.values)
plt.xlabel('Age')
plt.ylabel('Counts')
plt.show()

# %% [markdown]
# ## 직업군 분석

# %%
occupation_counts = df['occupation'].value_counts()
occupation_counts
# Out:
# 4     131032
# 0     130499
# 7     105425
# 1      85351
# 17     72816
# 20     60397
# 12     57214
# 2      50068
# 14     49109
# 16     46021
# 6      37205
# 3      31623
# 10     23290
# 15     22951
# 5      21850
# 11     20563
# 19     14904
# 13     13754
# 18     12086
# 9      11345
# 8       2706
# Name: occupation, dtype: int64

# %%
sns.barplot(x=occupation_counts.index, y=occupation_counts.values)
plt.xlabel('Occupoation')
plt.ylabel('Counts')
plt.show()

# %% [markdown]
# # 영화 별점 평균 상위 10개 영화

# %%
# 영화 제목별 별점의 평균
by_title = df.groupby(by='title')['rating'].mean()
by_title
# Out:
# title
# $1,000,000 Duck (1971)                        3.027027
# 'Night Mother (1986)                          3.371429
# 'Til There Was You (1997)                     2.692308
# 'burbs, The (1989)                            2.910891
# ...And Justice for All (1979)                 3.713568
#                                                 ...
# Zed & Two Noughts, A (1985)                   3.413793
# Zero Effect (1998)                            3.750831
# Zero Kelvin (Kjærlighetens kjøtere) (1995)    3.500000
# Zeus and Roxanne (1997)                       2.521739
# eXistenZ (1999)                               3.256098
# Name: rating, Length: 3706, dtype: float64

# %%
# by_title을 value의 내림차순 정렬 -> 첫 10개 선택: 별점 평균 상위 10개
by_title.sort_values(ascending=False).head(n=10)
# Out:
# title
# Ulysses (Ulisse) (1954)                      5.0
# Lured (1947)                                 5.0
# Follow the Bitch (1998)                      5.0
# Bittersweet Motel (2000)                     5.0
# Song of Freedom (1936)                       5.0
# One Little Indian (1973)                     5.0
# Smashing Time (1967)                         5.0
# Schlafes Bruder (Brother of Sleep) (1995)    5.0
# Gate of Heavenly Peace, The (1995)           5.0
# Baby, The (1973)                             5.0
# Name: rating, dtype: float64

# %%
# 별점 평균 하위 10개 : by_title을 value오름차순 정렬 -> 첫 10개 선택
by_title.sort_values(ascending=True).head(n=10)
# Out:
# title
# Elstree Calling (1930)                                        1.0
# Get Over It (1996)                                            1.0
# Venice/Venice (1992)                                          1.0
# Windows (1980)                                                1.0
# Kestrel's Eye (Falkens öga) (1998)                            1.0
# McCullochs, The (1975)                                        1.0
# Sleepover (1995)                                              1.0
# Torso (Corpi Presentano Tracce di Violenza Carnale) (1973)    1.0
# Spring Fever USA (a.k.a. Lauderdale) (1989)                   1.0
# Santa with Muscles (1996)                                     1.0
# Name: rating, dtype: float64

# %% [markdown]
# 별점의 개수가 1~2개 밖에 없는 영화들의 별점 평균을 계산하는 것은 큰 의미가 없을 것 같다. 일정 개수 이상의 별점 건수가 있는 영화들만 선택해서 별점 분석을 하는 것이 더 의미가 있을 것 같다.
#
# 영화별 별점 개수를 분석.

# %%
# 영화 제목별 별점 리뷰 개수
title_counts = df['title'].value_counts()
title_counts
# Out:
# American Beauty (1999)                                   3428
# Star Wars: Episode IV - A New Hope (1977)                2991
# Star Wars: Episode V - The Empire Strikes Back (1980)    2990
# Star Wars: Episode VI - Return of the Jedi (1983)        2883
# Jurassic Park (1993)                                     2672
#                                                          ...
# Waiting Game, The (2000)                                    1
# Shadows (Cienie) (1988)                                     1
# Juno and Paycock (1930)                                     1
# Resurrection Man (1998)                                     1
# Windows (1980)                                              1
# Name: title, Length: 3706, dtype: int64

# %%
title_counts.head(20)
# Out:
# American Beauty (1999)                                   3428
# Star Wars: Episode IV - A New Hope (1977)                2991
# Star Wars: Episode V - The Empire Strikes Back (1980)    2990
# Star Wars: Episode VI - Return of the Jedi (1983)        2883
# Jurassic Park (1993)                                     2672
# Saving Private Ryan (1998)                               2653
# Terminator 2: Judgment Day (1991)                        2649
# Matrix, The (1999)                                       2590
# Back to the Future (1985)                                2583
# Silence of the Lambs, The (1991)                         2578
# Men in Black (1997)                                      2538
# Raiders of the Lost Ark (1981)                           2514
# Fargo (1996)                                             2513
# Sixth Sense, The (1999)                                  2459
# Braveheart (1995)                                        2443
# Shakespeare in Love (1998)                               2369
# Princess Bride, The (1987)                               2318
# Schindler's List (1993)                                  2304
# L.A. Confidential (1997)                                 2288
# Groundhog Day (1993)                                     2278
# Name: title, dtype: int64

# %%
title_counts.describe()
# Out:
# count    3706.000000
# mean      269.889099
# std       384.047838
# min         1.000000
# 25%        33.000000
# 50%       123.500000
# 75%       350.000000
# max      3428.000000
# Name: title, dtype: float64

# %%
# 150건 이상의 별점 리뷰를 받은 영화 제목들
indexer = title_counts[title_counts >= 150].index

# %%
len(indexer) #> 150건 이상의 별점 리뷰를 받은 영화는 1683개
# Out:
# 1683

# %%
by_title_150 = by_title.loc[indexer]

# %%
# 별점 리뷰를 150건 이상 받은 영화들 중에서 별점 평균 상위 10위 이내인 영화 & 평점 평균
by_title_150.sort_values(ascending=False).head(n=10)
# Out:
# Seven Samurai (The Magnificent Seven) (Shichinin no samurai) (1954)    4.560510
# Shawshank Redemption, The (1994)                                       4.554558
# Godfather, The (1972)                                                  4.524966
# Close Shave, A (1995)                                                  4.520548
# Usual Suspects, The (1995)                                             4.517106
# Schindler's List (1993)                                                4.510417
# Wrong Trousers, The (1993)                                             4.507937
# Sunset Blvd. (a.k.a. Sunset Boulevard) (1950)                          4.491489
# Raiders of the Lost Ark (1981)                                         4.477725
# Rear Window (1954)                                                     4.476190
# Name: rating, dtype: float64

# %%
# 별점 리뷰를 150건 이상 받은 영화들 중에서 별점 평균 하위 10위 이내인 영화
by_title_150.sort_values(ascending = True).head(10)
# Out:
# Battlefield Earth (2000)                            1.611111
# Baby Geniuses (1999)                                1.701220
# Police Academy 5: Assignment: Miami Beach (1988)    1.766667
# Stop! Or My Mom Will Shoot (1992)                   1.782123
# Jaws 3-D (1983)                                     1.852381
# Speed 2: Cruise Control (1997)                      1.871935
# Spice World (1997)                                  1.873684
# Super Mario Bros. (1993)                            1.874286
# Home Alone 3 (1997)                                 1.876623
# Superman IV: The Quest for Peace (1987)             1.888554
# Name: rating, dtype: float64

# %% [markdown]
# # 성별 영화의 선호도
#
# 성별(gender), 제목(title)별 별점(rating)의 평균

# %%
# unstack(): 인덱스를 컬럼으로 변환
# stack(): 컬럼 이름을 행의 인덱스로 변환.
df.groupby(by=['title','gender'])['rating'].mean().unstack()
# Out:
# gender                                             F         M
# title
# $1,000,000 Duck (1971)                      3.375000  2.761905
# 'Night Mother (1986)                        3.388889  3.352941
# 'Til There Was You (1997)                   2.675676  2.733333
# 'burbs, The (1989)                          2.793478  2.962085
# ...And Justice for All (1979)               3.828571  3.689024
# ...                                              ...       ...
# Zed & Two Noughts, A (1985)                 3.500000  3.380952
# Zero Effect (1998)                          3.864407  3.723140
# Zero Kelvin (Kjærlighetens kjøtere) (1995)       NaN  3.500000
# Zeus and Roxanne (1997)                     2.777778  2.357143
# eXistenZ (1999)                             3.098592  3.289086
#
# [3706 rows x 2 columns]

# %%
by_gender = df.pivot_table(values='rating', index='title', columns='gender', aggfunc='mean')
# aggfunc='mean'은 생략 가능 : aggfunc 파라미터의 기본값은 'mean'이기 때문에.

# %%
by_gender
# Out:
# gender                                             F         M
# title
# $1,000,000 Duck (1971)                      3.375000  2.761905
# 'Night Mother (1986)                        3.388889  3.352941
# 'Til There Was You (1997)                   2.675676  2.733333
# 'burbs, The (1989)                          2.793478  2.962085
# ...And Justice for All (1979)               3.828571  3.689024
# ...                                              ...       ...
# Zed & Two Noughts, A (1985)                 3.500000  3.380952
# Zero Effect (1998)                          3.864407  3.723140
# Zero Kelvin (Kjærlighetens kjøtere) (1995)       NaN  3.500000
# Zeus and Roxanne (1997)                     2.777778  2.357143
# eXistenZ (1999)                             3.098592  3.289086
#
# [3706 rows x 2 columns]

# %%
# 150번 이상의 별점 리뷰를 받은 영화들
by_gender_150 = by_gender.loc[indexer]
by_gender_150
# Out:
# gender                                                     F         M
# American Beauty (1999)                              4.238901  4.347301
# Star Wars: Episode IV - A New Hope (1977)           4.302937  4.495307
# Star Wars: Episode V - The Empire Strikes Back ...  4.106481  4.344577
# Star Wars: Episode VI - Return of the Jedi (1983)   3.865237  4.069058
# Jurassic Park (1993)                                3.579407  3.814197
# ...                                                      ...       ...
# Asphalt Jungle, The (1950)                          3.571429  4.008130
# Tales from the Crypt Presents: Bordello of Bloo...  2.727273  2.565891
# Golden Voyage of Sinbad, The (1974)                 3.157895  3.431818
# In the Army Now (1994)                              2.384615  2.192000
# Police Academy 5: Assignment: Miami Beach (1988)    1.935484  1.722689
#
# [1683 rows x 2 columns]

# %%
# 여성 평점 평균 상위 10개 영화
by_gender_150.sort_values(by='F', ascending=False).head(10)
# Out:
# gender                                                     F         M
# Close Shave, A (1995)                               4.644444  4.473795
# Wrong Trousers, The (1993)                          4.588235  4.478261
# General, The (1927)                                 4.575758  4.329480
# Sunset Blvd. (a.k.a. Sunset Boulevard) (1950)       4.572650  4.464589
# Wallace & Gromit: The Best of Aardman Animation...  4.563107  4.385075
# Schindler's List (1993)                             4.562602  4.491415
# Grand Illusion (Grande illusion, La) (1937)         4.560976  4.266129
# Shawshank Redemption, The (1994)                    4.539075  4.560625
# Grand Day Out, A (1992)                             4.537879  4.293255
# To Kill a Mockingbird (1962)                        4.536667  4.372611

# %%
# 남성 별점 평균 상위 10개 영화
by_gender_150.sort_values(by='M', ascending=False).head(10)
# Out:
# gender                                                     F         M
# Godfather, The (1972)                               4.314700  4.583333
# Seven Samurai (The Magnificent Seven) (Shichini...  4.481132  4.576628
# Shawshank Redemption, The (1994)                    4.539075  4.560625
# Raiders of the Lost Ark (1981)                      4.332168  4.520597
# Usual Suspects, The (1995)                          4.513317  4.518248
# Star Wars: Episode IV - A New Hope (1977)           4.302937  4.495307
# Schindler's List (1993)                             4.562602  4.491415
# Paths of Glory (1957)                               4.392857  4.485149
# Wrong Trousers, The (1993)                          4.588235  4.478261
# Close Shave, A (1995)                               4.644444  4.473795

# %% [markdown]
# 성별 선호도의 차이가 큰 영화 --> 성별 별점 평균 차이 파생 변수(새로운 컬럼)추가

# %%
by_gender_150['diff'] = by_gender_150['M'] - by_gender_150['F']

# %%
by_gender_150
# Out:
# gender                                                     F         M  \
# American Beauty (1999)                              4.238901  4.347301
# Star Wars: Episode IV - A New Hope (1977)           4.302937  4.495307
# Star Wars: Episode V - The Empire Strikes Back ...  4.106481  4.344577
# Star Wars: Episode VI - Return of the Jedi (1983)   3.865237  4.069058
# Jurassic Park (1993)                                3.579407  3.814197
# ...                                                      ...       ...
# Asphalt Jungle, The (1950)                          3.571429  4.008130
# Tales from the Crypt Presents: Bordello of Bloo...  2.727273  2.565891
# Golden Voyage of Sinbad, The (1974)                 3.157895  3.431818
# In the Army Now (1994)                              2.384615  2.192000
# Police Academy 5: Assignment: Miami Beach (1988)    1.935484  1.722689
#
# gender                                                  diff
# American Beauty (1999)                              0.108400
# Star Wars: Episode IV - A New Hope (1977)           0.192371
# Star Wars: Episode V - The Empire Strikes Back ...  0.238096
# Star Wars: Episode VI - Return of the Jedi (1983)   0.203821
# Jurassic Park (1993)                                0.234791
# ...                                                      ...
# Asphalt Jungle, The (1950)                          0.436702
# Tales from the Crypt Presents: Bordello of Bloo... -0.161381
# Golden Voyage of Sinbad, The (1974)                 0.273923
# In the Army Now (1994)                             -0.192615
# Police Academy 5: Assignment: Miami Beach (1988)   -0.212795
#
# [1683 rows x 3 columns]

# %%
by_gender_150.sort_values(by='diff').head(n=10)
# Out:
# gender                                                     F         M  \
# Dirty Dancing (1987)                                3.790378  2.959596
# Home Alone 3 (1997)                                 2.486486  1.683761
# To Wong Foo, Thanks for Everything! Julie Newma...  3.486842  2.795276
# Jumpin' Jack Flash (1986)                           3.254717  2.578358
# Dracula: Dead and Loving It (1995)                  2.892857  2.250000
# Grease (1978)                                       3.975265  3.367041
# Police Academy 4: Citizens on Patrol (1987)         2.406250  1.802817
# Brokedown Palace (1999)                             3.312500  2.723577
# Relic, The (1997)                                   3.309524  2.723077
# Angels in the Outfield (1994)                       3.162500  2.580838
#
# gender                                                  diff
# Dirty Dancing (1987)                               -0.830782
# Home Alone 3 (1997)                                -0.802726
# To Wong Foo, Thanks for Everything! Julie Newma... -0.691567
# Jumpin' Jack Flash (1986)                          -0.676359
# Dracula: Dead and Loving It (1995)                 -0.642857
# Grease (1978)                                      -0.608224
# Police Academy 4: Citizens on Patrol (1987)        -0.603433
# Brokedown Palace (1999)                            -0.588923
# Relic, The (1997)                                  -0.586447
# Angels in the Outfield (1994)                      -0.581662

# %%
by_gender_150.sort_values(by='diff', ascending=False).head(n=10)
#> 여성들에 비해서 상대적으로 남성들의 선호도가 높은 영화
# Out:
# gender                                            F         M      diff
# Lifeforce (1985)                           2.250000  2.994152  0.744152
# Quest for Fire (1981)                      2.578947  3.309677  0.730730
# Good, The Bad and The Ugly, The (1966)     3.494949  4.221300  0.726351
# No Escape (1994)                           2.300000  2.994048  0.694048
# Kentucky Fried Movie, The (1977)           2.878788  3.555147  0.676359
# Tora! Tora! Tora! (1970)                   3.090909  3.737705  0.646796
# Up in Smoke (1978)                         2.944444  3.585227  0.640783
# Dumb & Dumber (1994)                       2.697987  3.336595  0.638608
# Friday the 13th: The Final Chapter (1984)  1.636364  2.258503  0.622140
# Longest Day, The (1962)                    3.411765  4.031447  0.619682

# %% [markdown]
# ## 성별에 상관 없이 선호도가 차이 큰 영화
#
# 별점 표준편차가 큰 영화

# %%
by_title = df.groupby(by='title')['rating'].agg(['mean','std'])

# %%
by_title
# Out:
#                                                 mean       std
# title
# $1,000,000 Duck (1971)                      3.027027  1.092563
# 'Night Mother (1986)                        3.371429  1.118636
# 'Til There Was You (1997)                   2.692308  1.020159
# 'burbs, The (1989)                          2.910891  1.107760
# ...And Justice for All (1979)               3.713568  0.878110
# ...                                              ...       ...
# Zed & Two Noughts, A (1985)                 3.413793  1.052794
# Zero Effect (1998)                          3.750831  1.042932
# Zero Kelvin (Kjærlighetens kjøtere) (1995)  3.500000  0.707107
# Zeus and Roxanne (1997)                     2.521739  1.122884
# eXistenZ (1999)                             3.256098  1.178568
#
# [3706 rows x 2 columns]

# %%
# 150건 이상의 별점 리뷰가 있는 영화들을 선택
by_title_150 = by_title.loc[indexer]

# %%
by_title_150
# Out:
#                                                         mean       std
# American Beauty (1999)                              4.317386  0.975133
# Star Wars: Episode IV - A New Hope (1977)           4.453694  0.800781
# Star Wars: Episode V - The Empire Strikes Back ...  4.292977  0.844432
# Star Wars: Episode VI - Return of the Jedi (1983)   4.022893  0.927356
# Jurassic Park (1993)                                3.763847  0.969777
# ...                                                      ...       ...
# Asphalt Jungle, The (1950)                          3.927152  0.833461
# Tales from the Crypt Presents: Bordello of Bloo...  2.589404  1.156267
# Golden Voyage of Sinbad, The (1974)                 3.397351  0.879996
# In the Army Now (1994)                              2.225166  1.020929
# Police Academy 5: Assignment: Miami Beach (1988)    1.766667  1.006133
#
# [1683 rows x 2 columns]

# %%
by_title_150.sort_values(by='std', ascending=False).head(10)
# Out:
#                                          mean       std
# Plan 9 from Outer Space (1958)       2.634538  1.455998
# Texas Chainsaw Massacre, The (1974)  3.222672  1.332448
# Dumb & Dumber (1994)                 3.192424  1.321333
# Blair Witch Project, The (1999)      3.031528  1.316368
# Natural Born Killers (1994)          3.144286  1.307198
# Idle Hands (1999)                    2.724638  1.298439
# Pink Flamingos (1972)                3.240506  1.293937
# Transformers: The Movie, The (1986)  3.380952  1.292917
# Very Bad Things (1998)               2.774194  1.280074
# Tank Girl (1995)                     2.614525  1.277695

# %%
# 선호도의 차이가 적은 영화: 표준편차 오름차순 정렬, 상위 10개 선택
by_title_150.sort_values(by='std', ascending=True).head(10)
# Out:
#                                                 mean       std
# Close Shave, A (1995)                       4.520548  0.667143
# Rear Window (1954)                          4.476190  0.688946
# Great Escape, The (1963)                    4.376437  0.692585
# Shawshank Redemption, The (1994)            4.554558  0.700443
# Wrong Trousers, The (1993)                  4.507937  0.708666
# Central Station (Central do Brasil) (1998)  4.283721  0.709393
# Never Cry Wolf (1983)                       3.981132  0.721782
# Soldier's Story, A (1984)                   3.737805  0.725206
# Raiders of the Lost Ark (1981)              4.477725  0.725647
# Seven Days in May (1964)                    4.254545  0.729639

# %% [markdown]
# # 영화 장르 분석
#
# * 150개 이상의 별점 리부를 받은 영화들중에서
#     * 별점 평균이 4.0 이상인 영화들의 장르 상위 10개
#     * 성별 별점 평균이 4.0 이상인 영화들의 장르 상위 10개
#     * 연령대별 별점 평균이 4.0 이상인 영화들의 장르 상위 10개

# %%
# DataFarme에서 영화 제목(title) 컬럼을 인덱스로 만듦.
df_with_index = df.set_index('title')

# %%
df_with_index
# Out:
#                                         user_id  movie_id  rating  timestamp  \
# title
# One Flew Over the Cuckoo's Nest (1975)        1      1193       5  978300760
# James and the Giant Peach (1996)              1       661       3  978302109
# My Fair Lady (1964)                           1       914       3  978301968
# Erin Brockovich (2000)                        1      3408       4  978300275
# Bug's Life, A (1998)                          1      2355       5  978824291
# ...                                         ...       ...     ...        ...
# Footloose (1984)                           4211      3791       2  965319075
# MacKenna's Gold (1969)                     4211      3806       3  965319138
# Pumpkinhead (1988)                         4211      3840       4  965319197
# Missing in Action (1984)                   4211      3766       2  965319138
# Bronco Billy (1980)                        4211      3834       2  965318885
#
#                                                               genres gender  \
# title
# One Flew Over the Cuckoo's Nest (1975)                         Drama      F
# James and the Giant Peach (1996)        Animation|Children's|Musical      F
# My Fair Lady (1964)                                  Musical|Romance      F
# Erin Brockovich (2000)                                         Drama      F
# Bug's Life, A (1998)                     Animation|Children's|Comedy      F
# ...                                                              ...    ...
# Footloose (1984)                                               Drama      M
# MacKenna's Gold (1969)                                       Western      M
# Pumpkinhead (1988)                                            Horror      M
# Missing in Action (1984)                                  Action|War      M
# Bronco Billy (1980)                          Adventure|Drama|Romance      M
#
#                                         age  occupation zip_code
# title
# One Flew Over the Cuckoo's Nest (1975)    1          10    48067
# James and the Giant Peach (1996)          1          10    48067
# My Fair Lady (1964)                       1          10    48067
# Erin Brockovich (2000)                    1          10    48067
# Bug's Life, A (1998)                      1          10    48067
# ...                                     ...         ...      ...
# Footloose (1984)                         45           5    77662
# MacKenna's Gold (1969)                   45           5    77662
# Pumpkinhead (1988)                       45           5    77662
# Missing in Action (1984)                 45           5    77662
# Bronco Billy (1980)                      45           5    77662
#
# [1000209 rows x 9 columns]

# %%
# 150개 이상의 별점 리뷰를 갖는 영화들만 선택한 부분집합
df_150 = df_with_index.loc[indexer]

# %%
title_over_4 = by_title_150[by_title_150['mean'] >= 4.0].index

# %%
title_over_4 #> 150개 이상의 별점이 4점이상의 리뷰를 갖는 영화의 타이틀
# Out:
# Index(['American Beauty (1999)', 'Star Wars: Episode IV - A New Hope (1977)',
#        'Star Wars: Episode V - The Empire Strikes Back (1980)',
#        'Star Wars: Episode VI - Return of the Jedi (1983)',
#        'Saving Private Ryan (1998)', 'Terminator 2: Judgment Day (1991)',
#        'Matrix, The (1999)', 'Silence of the Lambs, The (1991)',
#        'Raiders of the Lost Ark (1981)', 'Fargo (1996)',
#        ...
#        'Matewan (1987)', 'Shall We Dance? (1937)',
#        'Once Upon a Time in the West (1969)', 'Suspicion (1941)',
#        'Everest (1998)', 'Grand Illusion (Grande illusion, La) (1937)',
#        'Seven Days in May (1964)', 'Sullivan's Travels (1942)',
#        'Paradise Lost: The Child Murders at Robin Hood Hills (1996)',
#        'Pawnbroker, The (1965)'],
#       dtype='object', length=283)

# %%
df_with_index.loc[title_over_4]
# Out:
#                         user_id  movie_id  rating  timestamp        genres  \
# title
# American Beauty (1999)        2      2858       4  978298434  Comedy|Drama
# American Beauty (1999)       15      2858       4  978196348  Comedy|Drama
# American Beauty (1999)       17      2858       5  978159467  Comedy|Drama
# American Beauty (1999)       18      2858       5  978156168  Comedy|Drama
# American Beauty (1999)       19      2858       5  982210072  Comedy|Drama
# ...                         ...       ...     ...        ...           ...
# Pawnbroker, The (1965)     3186      3789       3  968699221         Drama
# Pawnbroker, The (1965)     3289      3789       4  968093748         Drama
# Pawnbroker, The (1965)     4045      3789       5  965498976         Drama
# Pawnbroker, The (1965)     4239      3789       4  965310021         Drama
# Pawnbroker, The (1965)     4230      3789       5  965312551         Drama
#
#                        gender  age  occupation zip_code
# title
# American Beauty (1999)      M   56          16    70072
# American Beauty (1999)      M   25           7    22903
# American Beauty (1999)      M   50           1    95350
# American Beauty (1999)      F   18           3    95825
# American Beauty (1999)      M    1          10    48073
# ...                       ...  ...         ...      ...
# Pawnbroker, The (1965)      M   50           1    92122
# Pawnbroker, The (1965)      M   45           6    95695
# Pawnbroker, The (1965)      M   56          13    40511
# Pawnbroker, The (1965)      M   50           7    52402
# Pawnbroker, The (1965)      M   56          13    34235
#
# [232721 rows x 9 columns]

# %%
movies_with_index = movies.set_index('title')

# %%
movies_with_index
# Out:
#                                     movie_id                        genres
# title
# Toy Story (1995)                           1   Animation|Children's|Comedy
# Jumanji (1995)                             2  Adventure|Children's|Fantasy
# Grumpier Old Men (1995)                    3                Comedy|Romance
# Waiting to Exhale (1995)                   4                  Comedy|Drama
# Father of the Bride Part II (1995)         5                        Comedy
# ...                                      ...                           ...
# Meet the Parents (2000)                 3948                        Comedy
# Requiem for a Dream (2000)              3949                         Drama
# Tigerland (2000)                        3950                         Drama
# Two Family House (2000)                 3951                         Drama
# Contender, The (2000)                   3952                Drama|Thriller
#
# [3883 rows x 2 columns]

# %%
movies_over_4 = movies_with_index.loc[title_over_4]

# %%
movies_over_4
# Out:
#                                                     movie_id  \
# American Beauty (1999)                                  2858
# Star Wars: Episode IV - A New Hope (1977)                260
# Star Wars: Episode V - The Empire Strikes Back ...      1196
# Star Wars: Episode VI - Return of the Jedi (1983)       1210
# Saving Private Ryan (1998)                              2028
# ...                                                      ...
# Grand Illusion (Grande illusion, La) (1937)             3134
# Seven Days in May (1964)                                3634
# Sullivan's Travels (1942)                               2936
# Paradise Lost: The Child Murders at Robin Hood ...      1361
# Pawnbroker, The (1965)                                  3789
#
#                                                                                  genres
# American Beauty (1999)                                                     Comedy|Drama
# Star Wars: Episode IV - A New Hope (1977)               Action|Adventure|Fantasy|Sci-Fi
# Star Wars: Episode V - The Empire Strikes Back ...    Action|Adventure|Drama|Sci-Fi|War
# Star Wars: Episode VI - Return of the Jedi (1983)   Action|Adventure|Romance|Sci-Fi|War
# Saving Private Ryan (1998)                                             Action|Drama|War
# ...                                                                                 ...
# Grand Illusion (Grande illusion, La) (1937)                                   Drama|War
# Seven Days in May (1964)                                                       Thriller
# Sullivan's Travels (1942)                                                        Comedy
# Paradise Lost: The Child Murders at Robin Hood ...                          Documentary
# Pawnbroker, The (1965)                                                            Drama
#
# [283 rows x 2 columns]

# %%
# 별점 평균 4.0 이상인 영화의 장르들을 저장할 리스트
genres_over_4 =[]
for s in movies_over_4['genres']:
  genres_over_4.extend(s.split(sep='|'))

# %%
len(genres_over_4)
# Out:
# 526

# %%
# 장르의 빈도수
genre_counts = pd.value_counts(genres_over_4)

# %%
genre_counts
# Out:
# Drama          134
# Comedy          82
# Thriller        51
# Romance         38
# War             36
# Action          36
# Crime           26
# Mystery         21
# Sci-Fi          19
# Adventure       17
# Film-Noir       16
# Western         12
# Animation       10
# Documentary     10
# Musical          8
# Horror           5
# Children's       4
# Fantasy          1
# dtype: int64

# %%
# 장르의 빈도수 상위 10개
genre_counts = genre_counts.head(10)

# %%
genre_counts
# Out:
# Drama        134
# Comedy        82
# Thriller      51
# Romance       38
# War           36
# Action        36
# Crime         26
# Mystery       21
# Sci-Fi        19
# Adventure     17
# dtype: int64

# %%
sns.barplot(x=genre_counts.values, y=genre_counts.index)
plt.show()

# %% [markdown]
# 150개 이상의 별점 리뷰를 가지고 있고, 여성들의 별점 평균이 4.0이상인 영화들에 나오는 장르들.

# %%
idx_female = by_gender_150[by_gender_150['F'] >= 4.0].index

# %%
idx_female
# Out:
# Index(['American Beauty (1999)', 'Star Wars: Episode IV - A New Hope (1977)',
#        'Star Wars: Episode V - The Empire Strikes Back (1980)',
#        'Saving Private Ryan (1998)', 'Matrix, The (1999)',
#        'Silence of the Lambs, The (1991)', 'Raiders of the Lost Ark (1981)',
#        'Fargo (1996)', 'Sixth Sense, The (1999)', 'Braveheart (1995)',
#        ...
#        'Once Were Warriors (1994)', 'Suspicion (1941)', 'Everest (1998)',
#        'Grand Illusion (Grande illusion, La) (1937)',
#        'Seven Days in May (1964)', 'Sullivan's Travels (1942)',
#        'Paradise Lost: The Child Murders at Robin Hood Hills (1996)',
#        'Pawnbroker, The (1965)', 'Dead Man (1995)', 'Twelfth Night (1996)'],
#       dtype='object', length=279)

# %%
female_movies = movies_with_index.loc[idx_female]

# %%
female_movies
# Out:
#                                                     movie_id  \
# American Beauty (1999)                                  2858
# Star Wars: Episode IV - A New Hope (1977)                260
# Star Wars: Episode V - The Empire Strikes Back ...      1196
# Saving Private Ryan (1998)                              2028
# Matrix, The (1999)                                      2571
# ...                                                      ...
# Sullivan's Travels (1942)                               2936
# Paradise Lost: The Child Murders at Robin Hood ...      1361
# Pawnbroker, The (1965)                                  3789
# Dead Man (1995)                                          714
# Twelfth Night (1996)                                     892
#
#                                                                                genres
# American Beauty (1999)                                                   Comedy|Drama
# Star Wars: Episode IV - A New Hope (1977)             Action|Adventure|Fantasy|Sci-Fi
# Star Wars: Episode V - The Empire Strikes Back ...  Action|Adventure|Drama|Sci-Fi|War
# Saving Private Ryan (1998)                                           Action|Drama|War
# Matrix, The (1999)                                             Action|Sci-Fi|Thriller
# ...                                                                               ...
# Sullivan's Travels (1942)                                                      Comedy
# Paradise Lost: The Child Murders at Robin Hood ...                        Documentary
# Pawnbroker, The (1965)                                                          Drama
# Dead Man (1995)                                                               Western
# Twelfth Night (1996)                                             Comedy|Drama|Romance
#
# [279 rows x 2 columns]

# %%
female_genres = [] # 여성 평균 4.0이상인 영화의 장르들을 저장할 리스트
for s in female_movies['genres']:
  female_genres.extend(s.split(sep='|'))

# %%
len(female_genres)
# Out:
# 511

# %%
# 여성 별점 평균 4.0 이상인 영화의 장르 개수 상위 10개
female_genre_counts = pd.value_counts(female_genres).head(10)

# %%
female_genre_counts
# Out:
# Drama        145
# Comedy        82
# Romance       47
# Thriller      40
# War           32
# Action        24
# Mystery       22
# Crime         21
# Musical       17
# Adventure     15
# dtype: int64

# %%
sns.barplot(x=female_genre_counts.values, y=female_genre_counts.index)
plt.show()

# %% [markdown]
# 150개 이상의 별점 리뷰를 가지고 있고, 남성들의 별점 평균이 4.0 이상인 영화 장르의 상위 10개

# %%
# 150개 이상의 별점 리뷰를 가지고 있고, 남성들의 별점 평균이 4.0 이상인 영화의 제목들
idx_male= by_gender_150[by_gender_150['M']>=4.0].index

# %%
# 남성 별점 평균이 4.0 이상인 영화들
movies_male = movies_with_index.loc[idx_male]

# %%
male_genres = []
for s in movies_male['genres']:
  male_genres.extend(s.split(sep='|'))

# %%
# 남성들의 선호도가 높은 장르 상위 10개
male_genre_counts = pd.value_counts(male_genres).head(10)

# %%
male_genre_counts
# Out:
# Drama        131
# Comedy        80
# Thriller      49
# Action        39
# War           36
# Romance       32
# Crime         26
# Sci-Fi        19
# Mystery       19
# Adventure     17
# dtype: int64

# %%
sns.barplot(x=male_genre_counts.values, y = male_genre_counts.index)
plt.show()

# %% [markdown]
# 150건 이상의 리뷰가 있는 영화들 중에서 선호도의 차이(별점의 표준편차)가 큰 영화 상위 50개 자주 등장하는 영화 장르 5개.

# %%
# 150건 이상의 리뷰가 있는 영화들 중에서 선호도의 차이가 큰 영화 상위 50개의 title
title_by_std_50 = df_with_index.loc[indexer].loc[indexer].groupby(by='title')['rating'].std().sort_values(ascending=False).head(50).index

# %%
movies_str_50 = movies_with_index.loc[title_by_std_50]
movies_str_50
# Out:
#                                                  movie_id  \
# title
# Plan 9 from Outer Space (1958)                       1924
# Texas Chainsaw Massacre, The (1974)                  2459
# Dumb & Dumber (1994)                                  231
# Blair Witch Project, The (1999)                      2710
# Natural Born Killers (1994)                           288
# Idle Hands (1999)                                    2606
# Pink Flamingos (1972)                                2361
# Transformers: The Movie, The (1986)                  1205
# Very Bad Things (1998)                               2387
# Tank Girl (1995)                                      327
# Hellraiser: Bloodline (1996)                          611
# Eraserhead (1977)                                    3676
# Rocky Horror Picture Show, The (1975)                2657
# Eyes Wide Shut (1999)                                2712
# Evita (1996)                                         1416
# Adventures of Rocky and Bullwinkle, The (2000)       3754
# Dancer in the Dark (2000)                            3910
# Billy Madison (1995)                                  216
# Fear and Loathing in Las Vegas (1998)                1884
# Bicentennial Man (1999)                              3156
# Twin Peaks: Fire Walk with Me (1992)                 3262
# Hellraiser (1987)                                    3917
# Babe: Pig in the City (1998)                         2384
# Wes Craven's New Nightmare (1994)                     366
# Superstar (1999)                                     2907
# In the Mouth of Madness (1995)                        407
# Halloween: The Curse of Michael Myers (1995)          891
# South Park: Bigger, Longer and Uncut (1999)          2700
# Big Hit, The (1998)                                  1866
# Deuce Bigalow: Male Gigolo (1999)                    3146
# Return from Witch Mountain (1978)                    2091
# Scary Movie (2000)                                   3785
# Cook the Thief His Wife & Her Lover, The (1989)      1173
# Hamlet (2000)                                        3598
# Serial Mom (1994)                                     532
# Haunting, The (1963)                                 2550
# Half Baked (1998)                                    1753
# Waterboy, The (1998)                                 2335
# Toys (1992)                                          2253
# Toxic Avenger, The (1985)                            3693
# Thin Red Line, The (1998)                            2427
# Ravenous (1999)                                      2560
# Last Temptation of Christ, The (1988)                2022
# Patch Adams (1998)                                   2431
# For Love of the Game (1999)                          2861
# BASEketball (1998)                                   2060
# Dracula: Dead and Loving It (1995)                     12
# Armageddon (1998)                                    1917
# Starship Troopers (1997)                             1676
# Godzilla (Gojira) (1954)                             2363
#
#                                                                                           genres
# title
# Plan 9 from Outer Space (1958)                                                     Horror|Sci-Fi
# Texas Chainsaw Massacre, The (1974)                                                       Horror
# Dumb & Dumber (1994)                                                                      Comedy
# Blair Witch Project, The (1999)                                                           Horror
# Natural Born Killers (1994)                                                      Action|Thriller
# Idle Hands (1999)                                                                  Comedy|Horror
# Pink Flamingos (1972)                                                                     Comedy
# Transformers: The Movie, The (1986)              Action|Animation|Children's|Sci-Fi|Thriller|War
# Very Bad Things (1998)                                                              Comedy|Crime
# Tank Girl (1995)                                                    Action|Comedy|Musical|Sci-Fi
# Hellraiser: Bloodline (1996)                                                Action|Horror|Sci-Fi
# Eraserhead (1977)                                                                   Drama|Horror
# Rocky Horror Picture Show, The (1975)                               Comedy|Horror|Musical|Sci-Fi
# Eyes Wide Shut (1999)                                                                      Drama
# Evita (1996)                                                                       Drama|Musical
# Adventures of Rocky and Bullwinkle, The (2000)                       Animation|Children's|Comedy
# Dancer in the Dark (2000)                                                          Drama|Musical
# Billy Madison (1995)                                                                      Comedy
# Fear and Loathing in Las Vegas (1998)                                               Comedy|Drama
# Bicentennial Man (1999)                                                      Comedy|Drama|Sci-Fi
# Twin Peaks: Fire Walk with Me (1992)                                               Drama|Mystery
# Hellraiser (1987)                                                                         Horror
# Babe: Pig in the City (1998)                                                   Children's|Comedy
# Wes Craven's New Nightmare (1994)                                                         Horror
# Superstar (1999)                                                                          Comedy
# In the Mouth of Madness (1995)                                                   Horror|Thriller
# Halloween: The Curse of Michael Myers (1995)                                     Horror|Thriller
# South Park: Bigger, Longer and Uncut (1999)                                     Animation|Comedy
# Big Hit, The (1998)                                                                Action|Comedy
# Deuce Bigalow: Male Gigolo (1999)                                                         Comedy
# Return from Witch Mountain (1978)                                              Children's|Sci-Fi
# Scary Movie (2000)                                                                 Comedy|Horror
# Cook the Thief His Wife & Her Lover, The (1989)                                            Drama
# Hamlet (2000)                                                                              Drama
# Serial Mom (1994)                                                            Comedy|Crime|Horror
# Haunting, The (1963)                                                             Horror|Thriller
# Half Baked (1998)                                                                         Comedy
# Waterboy, The (1998)                                                                      Comedy
# Toys (1992)                                                                Action|Comedy|Fantasy
# Toxic Avenger, The (1985)                                                          Comedy|Horror
# Thin Red Line, The (1998)                                                       Action|Drama|War
# Ravenous (1999)                                                                     Drama|Horror
# Last Temptation of Christ, The (1988)                                                      Drama
# Patch Adams (1998)                                                                  Comedy|Drama
# For Love of the Game (1999)                                                         Comedy|Drama
# BASEketball (1998)                                                                        Comedy
# Dracula: Dead and Loving It (1995)                                                 Comedy|Horror
# Armageddon (1998)                                               Action|Adventure|Sci-Fi|Thriller
# Starship Troopers (1997)                                             Action|Adventure|Sci-Fi|War
# Godzilla (Gojira) (1954)                                                           Action|Sci-Fi

# %%
std_50 = []
for g in movies_str_50['genres']:
  std_50.extend(g.split(sep='|'))

# %%
std_50_counts = pd.value_counts(std_50)
std_50_counts.head(5)
# Out:
# Comedy    25
# Horror    17
# Drama     14
# Sci-Fi    10
# Action    10
# dtype: int64

# %% [markdown]
# 연령대별(`18~24, 25~34, 35~44`)에서 평점 평균 상위 영화 제목, 장르

# %%
# 평점 평균을 title, age로 묶어주기
movies_age = df.groupby(by=['title', 'age'])['rating'].mean().unstack()
movies_age_150 = movies_age.loc[indexer]

# %%
# 연령 구간 리스트
age = [1, 18, 25, 35, 45, 50, 56]



ages = {}
for a in age:
   ages[a]= movies_age_150.sort_values(by=a, ascending=False).head(10).index

# 각 연령대별 평균 평점 상위 10개의 title
ages
# Out:
# {1: Index(['Breaking the Waves (1996)', 'Coming Home (1978)', 'Gaslight (1944)',
#         'Threesome (1994)', 'Once Upon a Time in the West (1969)',
#         'Seven Days in May (1964)', 'Night Shift (1982)', 'Dead Ringers (1988)',
#         'Shadowlands (1993)',
#         'Paradise Lost: The Child Murders at Robin Hood Hills (1996)'],
#        dtype='object'),
#  18: Index(['Usual Suspects, The (1995)', 'Shawshank Redemption, The (1994)',
#         'Seven Samurai (The Magnificent Seven) (Shichinin no samurai) (1954)',
#         'Close Shave, A (1995)', 'Life Is Beautiful (La Vita è bella) (1997)',
#         'American Beauty (1999)', 'Charade (1963)',
#         'Wrong Trousers, The (1993)', 'Godfather, The (1972)',
#         'Mona Lisa (1986)'],
#        dtype='object'),
#  25: Index(['Shawshank Redemption, The (1994)', 'Raiders of the Lost Ark (1981)',
#         'Godfather, The (1972)', 'Star Wars: Episode IV - A New Hope (1977)',
#         'Paths of Glory (1957)', 'Usual Suspects, The (1995)',
#         'Seven Samurai (The Magnificent Seven) (Shichinin no samurai) (1954)',
#         'Close Shave, A (1995)',
#         'Sunset Blvd. (a.k.a. Sunset Boulevard) (1950)', 'Rear Window (1954)'],
#        dtype='object'),
#  35: Index(['Sunset Blvd. (a.k.a. Sunset Boulevard) (1950)',
#         'To Kill a Mockingbird (1962)', 'City Lights (1931)',
#         'Godfather, The (1972)',
#         'Seven Samurai (The Magnificent Seven) (Shichinin no samurai) (1954)',
#         'Pawnbroker, The (1965)', 'Schindler's List (1993)',
#         'Shawshank Redemption, The (1994)', 'Rear Window (1954)',
#         'Raiders of the Lost Ark (1981)'],
#        dtype='object'),
#  45: Index(['Wrong Trousers, The (1993)',
#         'Bicycle Thief, The (Ladri di biciclette) (1948)',
#         'Close Shave, A (1995)', 'Schindler's List (1993)',
#         'Paths of Glory (1957)',
#         'Seven Samurai (The Magnificent Seven) (Shichinin no samurai) (1954)',
#         'Grand Illusion (Grande illusion, La) (1937)', 'Casablanca (1942)',
#         'To Kill a Mockingbird (1962)',
#         'Wallace & Gromit: The Best of Aardman Animation (1996)'],
#        dtype='object'),
#  50: Index(['Everest (1998)', 'Yojimbo (1961)', 'Real Genius (1985)',
#         'Wrong Trousers, The (1993)',
#         'Seven Samurai (The Magnificent Seven) (Shichinin no samurai) (1954)',
#         'Wallace & Gromit: The Best of Aardman Animation (1996)',
#         'Maltese Falcon, The (1941)', 'Close Shave, A (1995)',
#         'Shadow of a Doubt (1943)', 'Grand Day Out, A (1992)'],
#        dtype='object'),
#  56: Index(['Creature Comforts (1990)',
#         'Paradise Lost: The Child Murders at Robin Hood Hills (1996)',
#         'Nosferatu (Nosferatu, eine Symphonie des Grauens) (1922)',
#         'Better Off Dead... (1985)', 'Wrong Trousers, The (1993)',
#         'Seventh Seal, The (Sjunde inseglet, Det) (1957)', 'Eraserhead (1977)',
#         'Yojimbo (1961)', 'Inherit the Wind (1960)',
#         'To Kill a Mockingbird (1962)'],
#        dtype='object')}

# %%
# 연령 1~56 구간의 장르 개수 데이터 프레임으로 만들기
age_counts = pd.DataFrame()
for n in age:
  age_list=[]
  for g in movies_with_index.loc[ages[n].values]['genres']:
    age_list.extend(g.split(sep='|'))
  age_counts[n] = pd.value_counts(age_list)  
age_counts
# Out:
#              1    18   25   35   45   50   56
# Drama         4  5.0  4.0  7.0  7.0  2.0  5.0
# Thriller      3  4.0  3.0  1.0  1.0  2.0  NaN
# Comedy        2  6.0  1.0  1.0  2.0  5.0  4.0
# Romance       2  1.0  NaN  1.0  1.0  NaN  NaN
# War           1  NaN  1.0  1.0  4.0  NaN  NaN
# Mystery       1  1.0  1.0  1.0  NaN  1.0  NaN
# Western       1  NaN  NaN  NaN  NaN  1.0  1.0
# Documentary   1  NaN  NaN  NaN  NaN  1.0  1.0

# %%
# 연령 18, 25, 35 장르 개수 시각화
fig, ax = plt.subplots(ncols=3, figsize=(20,4))

sns.barplot(x= age_counts.index,y=age_counts[18].values, ax=ax[0])
sns.barplot(x= age_counts.index,y=age_counts[25].values, ax=ax[1])
sns.barplot(x= age_counts.index,y=age_counts[35].values, ax=ax[2])
plt.show()

# %% [markdown]
# __"college/grad student"__ 직업군에서 평점 평균 상위 영화 제목, 장르

# %%
# 4 직업군에서 상위 10개의 평점 평균
ocp_4_idx = df[df['occupation'] ==4].groupby(by=['title'])['rating'].mean().loc[indexer].sort_values(ascending=False).head(10).index

# 상위 10개의 영화 제목
ocp_4_idx
# Out:
# Index(['Shawshank Redemption, The (1994)',
#        'Sunset Blvd. (a.k.a. Sunset Boulevard) (1950)',
#        'Usual Suspects, The (1995)', 'Close Shave, A (1995)',
#        'Godfather, The (1972)', 'It Happened One Night (1934)',
#        'Paths of Glory (1957)', 'Treasure of the Sierra Madre, The (1948)',
#        'Wrong Trousers, The (1993)', 'To Sir with Love (1967)'],
#       dtype='object')

# %%
# 직업군 4의 상위 10개의 영화제목의 장르
ocp_4_genres = movies_with_index.loc[ocp_4_idx]

ocp_4_genres_list =[]

for g in ocp_4_genres['genres']:
  ocp_4_genres_list.extend(g.split(sep='|'))

# 직업군 4의 상위 10개의 장르 개수 
ocp_4_genres_counts = pd.value_counts(ocp_4_genres_list)
ocp_4_genres_counts
# Out:
# Drama        4
# Comedy       3
# Crime        2
# Thriller     2
# Animation    2
# Film-Noir    1
# Action       1
# War          1
# Adventure    1
# dtype: int64

# %%
# 직업군 4의 상위 10개의 장르 개수 그래프로 시각화
sns.barplot(x=ocp_4_genres_counts.index, y=ocp_4_genres_counts.values)
plt.show()
